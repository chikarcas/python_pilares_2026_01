# %%
print("Hola")
# Out:
# Hola

# %% [markdown]
# # Hola

# %%
Entero = 5
Flotante = 6.2
Cadena = "Texto"
Booleano = True

# %%
print(type(Entero))
print(type(Flotante))
print(type(Cadena))
print(type(Booleano))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
2+3
# Out:
# 5

# %%
6-2
# Out:
# 4

# %%
5*9.6
# Out:
# 48.0

# %%
2**9
# Out:
# 512

# %%
Flotante/Entero
# Out:
# 1.24

# %%
lista = [56,9.3547,"Adios",False]

# %%
print(lista)
# Out:
# [56, 9.3547, 'Adios', False]

# %%
print(type(lista))
# Out:
# <class 'list'>

# %%
print(lista[1])
# Out:
# 9.3547

# %%
print(lista[-1])
# Out:
# False

# %%
print(lista[-2])
# Out:
# Adios
